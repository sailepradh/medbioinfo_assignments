# %% [markdown]
# Course 1
#
#
# * Composition: Conditional execution
#
# * cmd1 data && cmd2 output_data
#
# * Be a good human unix citizen
#
# sysexit(0) --> Put your error code here
#
# echo $HOME
# echo $? --> error code
#
#
# * Pillar of unix commands
#
# stdin -->(0)  keyboard input  --> data input
# stdout --> (1) terminal output --> data oputput --> normal output
# std err -->(2)  terminal output --> data output --> errors and warnings
#
#
# * Pipeing connects stdout from one process to stdin in another process
#
#
# for example
# ```sh
# sort data | head
#
# ## this means read stdout from sort to stdin input of head
# ```
#
# Redirection !!
#
# * myprogram < infile > outfile
#
#     in your python program always write warnings stderr (systerr)
#
# * one tool for each basic task
#
# * general way of going -->
# raw2pure infile | analyze.py| present_graph
#
#
# * grep is another unix command to see the file containing the needed words for example "lasse" in output
#
# greo Lasse output| abalyze | grep Lasse > good.stuff
#
#
# How to catch error from standard error ?
#
#
# noisy_cmd input 2>&1 > output.file |grep lasse
#
# 2 here is standerr to standout and standout to ouptut file
#
# get rid of noise that means getting a lot of results
# noisy_cmd input 2>  /dev/null
#
#
# important files in unix
# /proc/
# /cpuinfo/
# /meminfo
#
# 2 concpets of unix command
# writing iteration
# writing shell script
#
#
# iteration
#
# ```sh
# ## for loop receipe
#
# for x in abc; do
#     echo $x
# done
#
# ## or
#
# for x in abc; do echo $x; done
# ```
# or using the globbing of whole file it can be done as
#
# ```sh
# for x in *.fasta; do
#     analyze $x
# done
# ```
#
# ```sh
# for i in $seq(1 10); do
#     echo $i
# done
#
# for i in $(ls *.fasta); do
#     ...
#  done
# ```
#
# Making jobs in background
#
# ```sh
# for x in *.fasta; do
#     analyze $x &
# done
#
# # here & means using the job in backgroung
# ```
#
# ```sh
# emacss &
#
# jobs ## Jobs running in background
# fg ## jobs in foreground bring in frint
# clt Z ## stop tje cp,,amd
# bg
#
# (sort data| analyze > result.txt) &
#
# ```
#
# runs emac in background
#
# Running things in parallel using GNU parallel
#
# ls *.fasta |  parallel analyze
#
#
# load balancing in the computing
#
# see it throuhgly
#
#
# executing shell script
#
# source filenames.sh
#
# $* --> all args
# $1 --> first args
# $2 --> second args
#
# so it can be set as
#
#
# source filename abc
#
# head.sh
#
# ```sh
# #! /bin/bash
#
# for f in $*; done
#     head $f
# done
# ```
#
# make it executable
#
# $ chmod +x heads.sh
#
#
# collect executables in bin directories
# ~/bin/
#
# instruct the OS to look for the programs in your bin directories you want to look in
#
# echo $PATH
#
# export PATH=$PATH~/bin  # add my bin directory to path # temporary storage of bin path
#
# and make it executable to it
#
#  long term solution for pesistence
#
#  ~/.bashrc
#
# put the "export ..." as one line in .bashrc

# %% [markdown]
# #### Day 2 Version control
#
# * system where ppl could work together
# * Central server holding for scr repo --> later not optimal --> Distributed repo
# * RCS, --> CVS, --> SVN --> git
# * Drills in git
# * git - add  --> add a file in git
# * git - commit --> commit from staging area to repository
# * git - find --> find differences between version
# * git - status --> find state of repo in relation with either the staging area or the hosting area
# * git - push --> copies changes from local repo to remore repo
# * git - init --> copies entire remote reopo to local machines
#
#
# What should be version controlled??
# * text file version controlled then binary files
# * scr code than binaries are version controlled
# * not bin directory should version controlled

# %% [markdown]
# set up files as suggested in the paper 1
#
# may be use make and snakemake kind of option according to use of shell script
#
# write to file in text and merge. Use .tex for versin handling with the google docs
